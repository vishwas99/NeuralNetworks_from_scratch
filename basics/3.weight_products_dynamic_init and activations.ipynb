# %%
import numpy as np

# %%
np.random.seed(0)

X = [1, 2, 3, 2.5]

# weights = [[0.2, 0.8, -0.5, 1.0],
#            [0.5, -0.91, 0.26, -0.5],
#            [-0.26, -0.27, 0.17, 0.87]]

# biases = [2, 3, 0.5]

# weights2 = [[0.1, -0.14, 0.5],
#             [-0.5, 0.12, -0.33],
#             [-0.44, 0.73, -0.13]]

# biases2 = [-1, 2, -0.5]

# %%
np.random.seed(0)
np.random.randn(3,4)
# Out:
# array([[ 1.76405235,  0.40015721,  0.97873798,  2.2408932 ],
#        [ 1.86755799, -0.97727788,  0.95008842, -0.15135721],
#        [-0.10321885,  0.4105985 ,  0.14404357,  1.45427351]])

# %%
class layer_dense:
    
    def __init__(self, n_inputs, n_neurons):
        self.weights = 0.10*np.random.randn(n_inputs, n_neurons)
        self.biases = np.zeros((1, n_neurons))
    
    def forward(self, inputs):
        self.op = np.dot(inputs, self.weights) + self.biases
        
class activation_relu:
    
    def forward(self, inputs):
        self.op = np.maximum(0, inputs)

layer1 = layer_dense(4, 5)
layer2 = layer_dense(5, 4)#no of op of layer1 is no of ip of layer2

layer1.forward(X)
print(layer1.op)

layer2.forward(layer1.op)
print(layer2.op)
# Out:
# [[-0.08183863 -0.12088873  0.43034258  0.53633118 -0.08341587]]
# [[ 0.08062322  0.05150197  0.0191755  -0.04737715]]

# %% [markdown]
# ## Activation functions

# %%
inputs = [0, 2, -1, 3.3, -2.7, 1.1, 2.2, -100]
output = []

for i in inputs:
    if i>0:
        output.append(i)
    else:
        output.append(0)

print(output)
# Out:
# [0, 2, 0, 3.3, 0, 1.1, 2.2, 0]

# %%
def spiral_data(points, classes):
    X = np.zeros((points*classes, 2))
    y = np.zeros(points*classes, dtype='uint8')
    for class_number in range(classes):
        ix = range(points*class_number, points*(class_number+1))
        r = np.linspace(0.0, 1, points)  # radius
        t = np.linspace(class_number*4, (class_number+1)*4, points) + np.random.randn(points)*0.2
        X[ix] = np.c_[r*np.sin(t*2.5), r*np.cos(t*2.5)]
        y[ix] = class_number
    return X, y

# %%
spx, spy = spiral_data(100, 4)

# %%
import matplotlib.pyplot as plt

plt.scatter(spx[:,0], spx[:,1])
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.scatter(spx[:,0], spx[:,1], ,cmap='brg')
